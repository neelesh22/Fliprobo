# %% [markdown]
# ## Q.1 Write a python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading" id="firstHeading" lang="en">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# ...

# %% [markdown]
# ## Q.2 Write a python program to display IMDB’s Top rated 100 movies’ data(i.e. Name, IMDB rating, duration, director, star cast - 10 main characters)

# %%
from bs4 import BeautifulSoup
import requests
import re

url = 'https://www.imdb.com/chart/top/?sort=ir,desc&mode=simple&page=1'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 100):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# 3 - The Godfather: Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# 4 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# 9 - Il buono, il brutto, il cattivo (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach
# ...

# %% [markdown]
# ## Q.3 Write a python program to display IMDB’s Top rated 100 Indian movies’ data(i.e. Name, IMDB rating, duration, director, star cast - 10 main characters)

# %%
from bs4 import BeautifulSoup
import requests
import re

url = 'https://www.imdb.com/india/top-rated-indian-movies/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=461131e5-5af0-4e50-bee2-223fad1e00ca&pf_rd_r=1F922EAB7ZBNHG8AP0PK&pf_rd_s=center-1&pf_rd_t=60601&pf_rd_i=india.toprated&ref_=fea_india_ss_toprated_india_tr_india250_hd'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, 100):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

indian_movies=pd.DataFrame(imdb)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - Pather Panchali (1955) - Starring: Satyajit Ray (dir.), Kanu Bannerjee, Karuna Bannerjee
# 2 - Ratsasan (2018) - Starring: Ram Kumar (dir.), Vishnu Vishal, Amala Paul
# 3 - Gol Maal (1979) - Starring: Hrishikesh Mukherjee (dir.), Amol Palekar, Bindiya Goswami
# 4 - Nayakan (1987) - Starring: Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan
# 5 - Anbe Sivam (2003) - Starring: Sundar C. (dir.), Kamal Haasan, Madhavan
# 6 - Apur Sansar (1959) - Starring: Satyajit Ray (dir.), Soumitra Chatterjee, Sharmila Tagore
# 7 - Natsamrat (2016) - Starring: Mahesh Manjrekar (dir.), Nana Patekar, Medha Manjrekar
# 8 - Pariyerum Perumal (2018) - Starring: Mari Selvaraj (dir.), Kathir, Anandhi
# 9 - Kireedam (1989) - Starring: Sibi Malayil (dir.), Mohanlal, Thilakan
# 1 -  Black Friday (2004) - Starring: Anurag Kashyap (dir.), Kay Kay Menon, Pawan Malhotra
# 11 - Manichitrathazhu (1993) - Starring: Fazil (dir.), Mohanlal, Shobana
# ...

# %% [markdown]
# ## Q.4 Write a python program to scrap book name, author name, genre and book review of 5 books from ‘www.bookpage.com’

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://bookpage.com/reviews'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
links = soup.find("div", {"class": "bp-well"}).findAll("div", {"class": "flex-article-content"})
book_list = []
for html in links:
    book = html.find("h4", {"class": "italic"}).find("a").get_text()
    author = html.find("p", {"class": "sans bold"}).get_text().strip()
    genre = html.find("p", {"class": "genre-links"}).find("a").get_text()
    review = html.find("p", {"class": ""})
    raw_list = [book, author, genre, review]
    book_list.append(raw_list)
test=pd.DataFrame(book_list)
test.columns =['Book_Name', 'Author', 'Genre', 'Review']

# %%
test
# Out:
#                   Book_Name                               Author       Genre  \
# 0   The Bad Muslim Discount                       Syed M. Masood     Fiction
# 1              Of a Feather                        Dayna Lorentz  Children's
# 2          Four Lost Cities                       Annalee Newitz  Nonfiction
# 3            ★ Mike Nichols                          Mark Harris  Nonfiction
# 4   ★ When Harry Met Minnie                      Martha Teichner  Nonfiction
# 5            Good Neighbors                         Sarah Langan     Fiction
# 6             Made in China                          Amelia Pang  Nonfiction
# 7         Hitler and Stalin                        Laurence Rees  Nonfiction
# 8       ★ The Other Mothers                      Jennifer Berney  Nonfiction
# 9   Milo Imagines the World  Matt de la Peña, Christian Robinson  Children's
#
#                                               Review
# 0                                               None
# ...

# %% [markdown]
# ## Q.5. Write a python program to scrap cricket rankings from ‘www.icc-cricket.com’. You have to scrap:
#
# ### i) Top 10 ODI teams.
# ### ii) Top 10 ODI Batsmen
# ### iii) Top 10 ODI bowlers

# %%
import urllib
import requests
from bs4 import BeautifulSoup
def ranking(url):
    page= requests.get(url)


    soup = BeautifulSoup(page.text, 'lxml')

    table = soup.find('table',{'class':'table'})


    data=[]
    for row in table.findAll('tr'):
        link = row.findAll('td')
        if len(link) == 5:
            data.append(link[1].text.strip())
                
    df = pd.DataFrame(data) 
    df=df[0:10]
    return df
url="https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
url2="https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
url3="https://www.icc-cricket.com/rankings/mens/player-rankings/test/bowling"
teams=ranking(url)
batsmen=ranking(url2)
bowlers=ranking(url3)
result=pd.concat([teams,batsmen,bowlers],axis=1, join='inner')
result.columns =['Top10 Teams', 'Top10 Batsmen', 'Top10 Bowlers'] 
result
# Out:
#         Top10 Teams        Top10 Batsmen        Top10 Bowlers
# 0      England\nENG          Virat Kohli          Pat Cummins
# 1        India\nIND         Rohit Sharma         Stuart Broad
# 2   New Zealand\nNZ           Babar Azam          Neil Wagner
# 3    Australia\nAUS          Ross Taylor       Josh Hazlewood
# 4  South Africa\nSA          Aaron Finch          Tim Southee
# 5     Pakistan\nPAK  Francois du Plessis       James Anderson
# 6   Bangladesh\nBAN         David Warner        Kagiso Rabada
# 7     Sri Lanka\nSL      Kane Williamson  Ravichandran Ashwin
# 8   West Indies\nWI      Quinton de Kock       Jasprit Bumrah
# 9  Afghanistan\nAFG       Jonny Bairstow         Jason Holder

# %% [markdown]
# ## Q.6. Write a python program to scrap cricket rankings from ‘www.icc-cricket.com’. You have to scrap: (Women)
# ### i) Top 10 ODI teams.
# ### ii) Top 10 ODI Batsmen
# ### iii) Top 10 ODI bowlers

# %%
import urllib
import requests
from bs4 import BeautifulSoup
def ranking(url):
    page= requests.get(url)


    soup = BeautifulSoup(page.text, 'lxml')

    table = soup.find('table',{'class':'table'})


    data=[]
    for row in table.findAll('tr'):
        link = row.findAll('td')
        if len(link) == 5:
            data.append(link[1].text.strip())
                
    df = pd.DataFrame(data) 
    df=df[0:10]
    return df
url="https://www.icc-cricket.com/rankings/womens/team-rankings/odi"
url2="https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting"
url3="https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling"
teams=ranking(url)
batsmen=ranking(url2)
bowlers=ranking(url3)
result=pd.concat([teams,batsmen,bowlers],axis=1, join='inner')
result.columns =['Top10 Teams', 'Top10 Batsmen', 'Top10 Bowlers'] 
result
# Out:
#         Top10 Teams      Top10 Batsmen   Top10 Bowlers
# 0    Australia\nAUS        Meg Lanning   Jess Jonassen
# 1        India\nIND    Stafanie Taylor    Megan Schutt
# 2      England\nENG       Alyssa Healy  Marizanne Kapp
# 3  South Africa\nSA    Smriti Mandhana  Shabnim Ismail
# 4   New Zealand\nNZ  Amy Satterthwaite  Jhulan Goswami
# 5   West Indies\nWI     Tammy Beaumont    Poonam Yadav
# 6     Pakistan\nPAK    Laura Wolvaardt   Shikha Pandey
# 7   Bangladesh\nBAN       Ellyse Perry    Ellyse Perry
# 8     Sri Lanka\nSL        Mithali Raj  Anya Shrubsole
# 9      Ireland\nIRE        Lizelle Lee   Deepti Sharma

# %% [markdown]
# ## Q.7 Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
import bs4
from bs4 import BeautifulSoup
import requests
import pandas as pd

no_pages = 2

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.amazon.in/gp/bestsellers/electronics/1389432031/ref=amb_link_1?pf_rd_m=A1VBAL9TL5WCBF&pf_rd_s=merchandised-search-1&pf_rd_r=4508BV307PEWKK4W2T2M&pf_rd_r=4508BV307PEWKK4W2T2M&pf_rd_t=101&pf_rd_p=984e7ab0-2561-4b96-bfcf-e92188007f0a&pf_rd_p=984e7ab0-2561-4b96-bfcf-e92188007f0a&pf_rd_i=1389432031'+str(pageNo)+'?ie=UTF8&pg='+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('div', attrs={'class':'a-section a-spacing-none aok-relative'}):
        #print(d)
        product_name = d.find('span', attrs={'class':'zg-text-center-align'})
        n = product_name.find_all('img', alt=True)
        #print(n[0]['alt'])
        img_url = d.find('a', attrs={'class':'a-size-small a-link-child'})
        rating = d.find('span', attrs={'class':'a-icon-alt'})
        users_rated = d.find('a', attrs={'class':'a-size-small a-link-normal'})
        price = d.find('span', attrs={'class':'p13n-sc-price'})

        all1=[]

        if product_name is not None:
            #print(n[0]['alt'])
            all1.append(n[0]['alt'])
        else:
            all1.append("unknown-product")

        if rating is not None:
            #print(rating.text)
            all1.append(rating.text)
        else:
            all1.append('-1')

        if users_rated is not None:
            #print(price.text)
            all1.append(users_rated.text)
        else:
            all1.append('0')     

        if price is not None:
            #print(price.text)
            all1.append(price.text)
        else:
            all1.append('0')
        alls.append(all1)    
    return alls

results = []
for i in range(1, no_pages+1):
    results.append(get_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['Product Name','Rating','Customers_Rated', 'Price'])
df.to_csv('amazon_products.csv', index=False, encoding='utf-8')

df[:9]
# Out:
#                                         Product Name              Rating  \
# 0          Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)  4.0 out of 5 stars
# 1     Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)  4.2 out of 5 stars
# 2  Samsung Galaxy M31 Prime Edition (Space Black,...  4.2 out of 5 stars
# 3         Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage)  4.2 out of 5 stars
# 4  Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...  3.7 out of 5 stars
# 5  Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...  4.2 out of 5 stars
# 6  Redmi Note 9 Pro (Aurora Blue, 4GB RAM, 64GB S...  4.2 out of 5 stars
# 7  Samsung Galaxy M02s (Blue,3GB RAM, 32GB Storag...  3.8 out of 5 stars
# 8  Redmi Note 9 Pro Max (Aurora Blue, 6GB RAM, 64...  4.1 out of 5 stars
#
#   Customers_Rated        Price
# 0          10,222   ₹ 8,999.00
# 1          12,595   ₹ 7,499.00
# 2        1,28,911  ₹ 16,499.00
# 3          12,595   ₹ 6,999.00
# 4           1,976  ₹ 10,999.00
# 5        1,28,911  ₹ 16,499.00
# ...

# %% [markdown]
# ## Q.8 Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city. The data should include period, short description, temperature and description.

# %%
from bs4 import BeautifulSoup
import requests

page = requests.get("http://forecast.weather.gov/MapClick.php?lat=37.78&lon=-122.42")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]

period=tonight.find(class_="period-name").get_text()
short_desc=tonight.find(class_="short-desc").get_text()
temp=tonight.find(class_="temp").get_text()
img = tonight.find("img")
desc = img['title']

period_tags=seven_day.select(".tombstone-container .period-name")
periods=[pt.get_text() for pt in period_tags]
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]

import pandas as pd
weather = pd.DataFrame({
        "period": periods,
         "short_desc": short_descs,
         "temp": temps,
         "desc":descs
    })
weather
# Out:
#           period                  short_desc         temp  \
# 0        Tonight                Mostly Clear   Low: 43 °F
# 1         Friday                       Sunny  High: 63 °F
# 2    FridayNight                Mostly Clear   Low: 45 °F
# 3       Saturday                       Sunny  High: 64 °F
# 4  SaturdayNight               Partly Cloudy   Low: 46 °F
# 5         Sunday  Patchy Fogthen MostlySunny  High: 62 °F
# 6    SundayNight               Mostly Cloudy   Low: 47 °F
# 7         Monday                Partly Sunny  High: 60 °F
# 8    MondayNight               Partly Cloudy   Low: 46 °F
#
#                                                 desc
# 0  Tonight: Mostly clear, with a low around 43. W...
# 1  Friday: Sunny, with a high near 63. Calm wind ...
# 2  Friday Night: Mostly clear, with a low around ...
# 3  Saturday: Sunny, with a high near 64. South wi...
# 4  Saturday Night: Partly cloudy, with a low arou...
# 5  Sunday: Patchy fog before 7am.  Otherwise, mos...
# ...
